# %%
import csv
import json
import re

# %%
filesys_path  = 'files/'
file_data_in  = 'Data_Scores_aznetz_Details_20200424.txt'
file_json_out = 'aznetz_Details_20200424.json'
file_csv_out  = 'aznetz_Details_20200424.csv'

# %%
def add2matrix(matrix,key,value):
    try:
        matrix[key] = matrix[key]+[value]
    except KeyError:
        matrix[key] = []
    return matrix

# %%
def initialize():
    vars = {
    "portals" : ["AAZ","BAT","BLZ","BZB","GTB","LIZ","OT","SOZ"],
    "portals_i" : 0,
    "flag" : 0,
    "current_portal" : '',
    "current_section" : '',
    "current_key" : '',
    "matrix" : {}
    }
    return vars

# %%
vars = initialize()
with open(filesys_path+file_data_in,'r',encoding="utf-8") as csvfile:
    reader = csv.reader(csvfile, delimiter=';', quotechar='"') # Delimiter darf nicht Komma sein!
    for row in reader:
        try:
            row[0]
            if row[0] == "Summe":
                if vars["flag"] == 0:
                    vars["current_section"] = 'APP-LIVE'
                    vars["flag"] = 1
                    vars["current_portal"] = vars["portals"][vars["portals_i"]]
                    vars["portals_i"] = vars["portals_i"] + 1
                elif vars["flag"] == 1:
                    vars["flag"] = 0
                    vars["current_section"] = 'WEB'
                else:
                    pass
                vars["current_key"] = ' '.join([vars["current_portal"],vars["current_section"]])
            vars["matrix"] = add2matrix(vars["matrix"],vars["current_key"],row[0].replace(',',''))
        except:
            pass
    print(vars["matrix"])
# Out:
# {'AAZ APP-LIVE': ['4490981', '1365976', '75.51', '00:46:02', '02:31:08'], 'AAZ WEB': ['10270497', '2702337', '87.21', '00:30:13', '01:54:08'], 'BAT APP-LIVE': ['114956', '33327', '79.15', '00:42:21', '02:25:24'], 'BAT WEB': ['311892', '83476', '83.48', '00:28:36', '01:41:30'], 'BLZ APP-LIVE': ['1419580', '468005', '69.72', '00:49:28', '02:29:49'], 'BLZ WEB': ['32', '14', '29.00', '00:04:16', '00:29:49'], 'BZB APP-LIVE': ['310365', '105288', '67.74', '00:49:38', '02:26:05'], 'BZB WEB': ['3326857', '943235', '81.33', '00:33:53', '01:58:31'], 'GTB APP-LIVE': ['105747', '32619', '74.39', '00:43:17', '02:19:22'], 'GTB WEB': ['286414', '71629', '91.13', '00:24:40', '01:35:13'], 'LIZ APP-LIVE': ['155231', '56505', '63.12', '00:44:47', '02:02:52'], 'LIZ WEB': ['350792', '117530', '69.03', '00:27:09', '01:21:14'], 'OT APP-LIVE': ['376230', '122752', '70.36', '00:41:26', '02:06:34'], 'OT WEB': ['599155', '153661', '89.60', '00:32:49', '02:06:00'], 'SOZ APP-LIVE': ['954910', '304841', '71.97', '00:44:40', '02:19:39'], 'SOZ WEB': ['1729211', '432474', '91.77', '00:28:27', '01:52:31']}

# %%
#print(json.dumps(matrix3d))
f = open(filesys_path+file_json_out,"w")
f.write(json.dumps(matrix))
f.close()

# %%
import pandas as pd

# %%
df = pd.read_json(filesys_path+file_json_out)

# %%
df.T
# Out:
#                        0          1      2         3         4
# AAZ APP-LIVE   4,490,981  1,365,976  75.51  00:46:02  02:31:08
# AAZ WEB       10,270,497  2,702,337  87.21  00:30:13  01:54:08
# BAT APP-LIVE     114,956     33,327  79.15  00:42:21  02:25:24
# BAT WEB          311,892     83,476  83.48  00:28:36  01:41:30
# BLZ APP-LIVE   1,419,580    468,005  69.72  00:49:28  02:29:49
# BLZ WEB               32         14  29.00  00:04:16  00:29:49
# BZB APP-LIVE     310,365    105,288  67.74  00:49:38  02:26:05
# BZB WEB        3,326,857    943,235  81.33  00:33:53  01:58:31
# GTB APP-LIVE     105,747     32,619  74.39  00:43:17  02:19:22
# GTB WEB          286,414     71,629  91.13  00:24:40  01:35:13
# LIZ APP-LIVE     155,231     56,505  63.12  00:44:47  02:02:52
# LIZ WEB          350,792    117,530  69.03  00:27:09  01:21:14
# OT APP-LIVE      376,230    122,752  70.36  00:41:26  02:06:34
# OT WEB           599,155    153,661  89.60  00:32:49  02:06:00
# SOZ APP-LIVE     954,910    304,841  71.97  00:44:40  02:19:39
# SOZ WEB        1,729,211    432,474  91.77  00:28:27  01:52:31

# %%
df.T.to_csv(filesys_path+file_csv_out)
