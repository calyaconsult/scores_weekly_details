# %%
import csv
import json

# %%
filesys_path  = 'files/'
file_data_in  = 'Data_Scores_aznetz_Details_20200427.txt'
file_json_out = 'aznetz_Details_20200424.json'
file_csv_out  = 'aznetz_Details_20200424.csv'

# %%
def add2matrix(matrix,key,value):
    try:
        matrix[key] = matrix[key]+[value]
    except KeyError:
        matrix[key] = []
    return matrix

# %%
def initialize():
    vars = {
    "portals" : ["AAZ","BAT","BLZ","BZB","GTB","LIZ","OT","SOZ"],
    "portals_i" : 0,
    "flag" : 0,
    "current_portal" : '',
    "current_section" : '',
    "current_key" : '',
    "matrix" : {}
    }
    return vars

# %%
def insert_empty_row(matrix,ptl,section):
    #print(matrix)
    key = ' '.join([ptl,section])
    #print("ptl: %s, section: %s key: %s" % (ptl,section,key))
    #print(key)
    for i in range(0,6):
        matrix = add2matrix(matrix,key,0)
    return matrix

# %%
vars = initialize()
with open(filesys_path+file_data_in,'r',encoding="utf-8") as csvfile:
    reader = csv.reader(csvfile, delimiter=';', quotechar='"') # Delimiter darf nicht Komma sein!
    for row in reader:
        try:
            row[0]
            if row[0]=="Summe":
                if vars["flag"] == 0:
                    vars["current_portal"] = vars["portals"][vars["portals_i"]]
                    vars["matrix"] = insert_empty_row(vars["matrix"],vars["current_portal"],"APP-EPAPER")
                    vars["current_section"] = 'APP-LIVE'
                    vars["flag"] = 1
                    vars["portals_i"] = vars["portals_i"] + 1
                elif vars["flag"] == 1:
                    vars["flag"] = 0
                    vars["current_section"] = 'WEB'
                else:
                    pass
            vars["current_key"] = ' '.join([vars["current_portal"],vars["current_section"]])
            vars["matrix"] = add2matrix(vars["matrix"],vars["current_key"],row[0].replace(',',''))
        except IndexError:
            pass
print(vars["matrix"])
# Out:
# {'AAZ APP-EPAPER': [0, 0, 0, 0, 0], 'AAZ APP-LIVE': ['5018630', '1525782', '85.41', '00:51:37', '02:49:33'], 'AAZ WEB': ['11430895', '3004153', '98.76', '00:33:47', '02:07:46'], 'BAT APP-EPAPER': [0, 0, 0, 0, 0], 'BAT APP-LIVE': ['129275', '37196', '90.25', '00:47:21', '02:43:48'], 'BAT WEB': ['353828', '92435', '97.71', '00:31:27', '01:54:01'], 'BLZ APP-EPAPER': [0, 0, 0, 0, 0], 'BLZ APP-LIVE': ['1588355', '523052', '78.91', '00:55:49', '02:49:17'], 'BLZ WEB': ['32', '14', '29.00', '00:04:16', '00:29:49'], 'BZB APP-EPAPER': [0, 0, 0, 0, 0], 'BZB APP-LIVE': ['346692', '117953', '76.33', '00:56:12', '02:44:52'], 'BZB WEB': ['3678386', '1052400', '90.94', '00:38:29', '02:13:13'], 'GTB APP-EPAPER': [0, 0, 0, 0, 0], 'GTB APP-LIVE': ['117784', '36534', '83.59', '00:48:52', '02:36:31'], 'GTB WEB': ['310291', '78458', '101.66', '00:28:16', '01:47:46'], 'LIZ APP-EPAPER': [0, 0, 0, 0, 0], 'LIZ APP-LIVE': ['175035', '63443', '71.70', '00:50:29', '02:19:10'], 'LIZ WEB': ['391106', '130490', '78.31', '00:30:27', '01:31:19'], 'OT APP-EPAPER': [0, 0, 0, 0, 0], 'OT APP-LIVE': ['419356', '137353', '79.22', '00:46:44', '02:22:15'], 'OT WEB': ['652888', '170537', '99.14', '00:37:55', '02:22:14'], 'SOZ APP-EPAPER': [0, 0, 0, 0, 0], 'SOZ APP-LIVE': ['1063410', '341347', '80.88', '00:50:29', '02:36:56'], 'SOZ WEB': ['1891865', '480838', '101.86', '00:32:31', '02:06:10']}

# %%
f = open(filesys_path+file_json_out,"w")
f.write(json.dumps(vars["matrix"]))
f.close()

# %%
import pandas as pd

# %%
df = pd.read_json(filesys_path+file_json_out)

# %%
df.T
# Out:
#                        0        1       2         3         4
# AAZ APP-EPAPER         0        0       0         0         0
# AAZ APP-LIVE     5018630  1525782   85.41  00:51:37  02:49:33
# AAZ WEB         11430895  3004153   98.76  00:33:47  02:07:46
# BAT APP-EPAPER         0        0       0         0         0
# BAT APP-LIVE      129275    37196   90.25  00:47:21  02:43:48
# BAT WEB           353828    92435   97.71  00:31:27  01:54:01
# BLZ APP-EPAPER         0        0       0         0         0
# BLZ APP-LIVE     1588355   523052   78.91  00:55:49  02:49:17
# BLZ WEB               32       14   29.00  00:04:16  00:29:49
# BZB APP-EPAPER         0        0       0         0         0
# BZB APP-LIVE      346692   117953   76.33  00:56:12  02:44:52
# BZB WEB          3678386  1052400   90.94  00:38:29  02:13:13
# GTB APP-EPAPER         0        0       0         0         0
# GTB APP-LIVE      117784    36534   83.59  00:48:52  02:36:31
# GTB WEB           310291    78458  101.66  00:28:16  01:47:46
# LIZ APP-EPAPER         0        0       0         0         0
# LIZ APP-LIVE      175035    63443   71.70  00:50:29  02:19:10
# LIZ WEB           391106   130490   78.31  00:30:27  01:31:19
# OT APP-EPAPER          0        0       0         0         0
# OT APP-LIVE       419356   137353   79.22  00:46:44  02:22:15
# OT WEB            652888   170537   99.14  00:37:55  02:22:14
# SOZ APP-EPAPER         0        0       0         0         0
# SOZ APP-LIVE     1063410   341347   80.88  00:50:29  02:36:56
# SOZ WEB          1891865   480838  101.86  00:32:31  02:06:10

# %%
df.T.to_csv(filesys_path+file_csv_out)
